# %%
#@title Setup boltzgen and download models
#@markdown Takes around 2 minutes for setup and download
import subprocess
import pathlib
from google.colab import drive

sep = '\n==========================\n'

# Install boltzgen
try:
  subprocess.run(["boltzgen", "run", "-h"], capture_output=True)
  print("Boltzgen is installed", end=sep)
except Exception as e:
  print("Boltzgen is not installed. Install it using pip", end=sep)
  # !pip install boltzgen

# Get github repo (maybe reverse order to get always the current version)
if not pathlib.Path("boltzgen").exists():
  # !git clone https://github.com/HannesStark/boltzgen.git
else:
  print("Boltzgen git is already cloned. Using it.", end=sep)

# Download models
cache = 'models'
# !export HF_HOME={cache}
if not pathlib.Path(cache).exists():
  print("Downloading models", end=sep)
  pathlib.Path(cache).mkdir(parents=True, exist_ok=True)
  # !boltzgen download all --cache {cache}
else:
  print("Models already downloaded. Using it.", end=sep)

# Print setup specifications
try:
  import torch
  print("Setup specifications:")
  print(f'   CUDA: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None"}')
  print(f'   pytorch: {torch.__version__}')
  mem = torch.cuda.get_device_properties(0).total_memory
  mem = round(mem / 1024**3, 2)
  print(f'   memory: {mem} GB')
except Exception as e:
  print(f'Error: {e}')
# Out:
# Boltzgen is installed
# ==========================
# Boltzgen git is already cloned. Using it.
# ==========================
# Models already downloaded. Using it.
# ==========================
# Setup specifications:
#    CUDA: Tesla T4
#    pytorch: 2.8.0+cu126
#    memory: 14.74 GB

# %%
# Command takes in an inital test 43 min to run !!!
cmd = ['boltzgen', 'run', 'boltzgen/example/vanilla_protein/1g13prot.yaml']
flags = [
  '--output workbench/test_run',
  '--protocol protein-anything',
  '--num_designs 10',
  '--budget 2',
  f'--cache {cache}'
]
cmd += flags
# !{' '.join(cmd)}
# Out:
# === Configuring pipeline ===
# Using dataset artifact: models/datasets--boltzgen--inference-data/snapshots/c3d36fd276e9caf098c75d4113c6d5eb320b1a4c/mols.zip
# ************** Checking design spec: boltzgen/example/vanilla_protein/1g13prot.yaml **************
# Total designed residues: 113
# Design specification visualization is written to workbench/test_run/1g13prot.cif
# **************************************************************************************************
# Using kernels: False [device capability: (7, 5)]
# Config overrides for protocol protein-anything: {}
# Using 1 devices
# Raw designs will be saved to: workbench/test_run/intermediate_designs
# Using diffusion batch size: 1
# Number of diffusion batches: 10
# Using model artifact: models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltzgen1_diverse.ckpt
# Using model artifact: models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltzgen1_adherence.ckpt
# Inverse-folded designs will be saved to: workbench/test_run/intermediate_designs_inverse_folded
# Using model artifact: models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltzgen1_ifold.ckpt
# Using model artifact: models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltz2_conf_final.ckpt
# Using model artifact: models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltz2_conf_final.ckpt
# Final ranked designs will be saved to: workbench/test_run/final_ranked_designs
# [1] design
# [2] inverse_folding
# [3] folding
# [4] design_folding
# [5] analysis
# [6] filtering
# Renaming existing config directory to workbench/test_run/previous-config-1
# Configuration complete. Configs written to workbench/test_run/config
# Steps manifest written to workbench/test_run/steps.yaml
#
# === Executing pipeline ===
# **************************************************
# Pipeline step 1 of 6: design
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/design.yaml
# 2025-10-27 10:43:27.876429: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761561807.906122    2776 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761561807.924207    2776 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761561807.952532    2776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761561807.952561    2776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761561807.952566    2776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761561807.952569    2776 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-27 10:43:27.956769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Step 1/6] design - Predicting DataLoader 0: :   0% 0/10 [00:00<?, ?it/s]Switched step_scale to 2.0
# Switched noise_scale to 0.88
# Loaded weights from models/models--boltzgen--boltzgen-1/snapshots/902d85ba4713ce8a42875bdad59b8467e6ae7561/boltzgen1_adherence.ckpt
# Switched checkpoint.
# Switched step_scale to 1.8
# Switched noise_scale to 0.95
# Switched step_scale to 2.0
# Switched noise_scale to 0.88
# [Step 1/6] design - Predicting DataLoader 0: : 100% 10/10 [13:37<00:00, 81.74s/it]Number of failed examples: 0
# [Step 1/6] design - Predicting DataLoader 0: : 100% 10/10 [13:37<00:00, 81.74s/it]
# ✓ Step design completed successfully in 888.4s
# **************************************************
# Pipeline step 2 of 6: inverse_folding
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/inverse_folding.yaml
# Initializing FromGeneratedDataModule datasets for workbench/test_run/intermediate_designs
# [Info] Number of files to process (including already processed ones): 10
# Found 1 targets and 10 remaining designs that still need to be processed in this step.
# 2025-10-27 10:57:32.621481: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761562652.641991    6536 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761562652.647988    6536 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761562652.668339    6536 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761562652.668372    6536 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761562652.668376    6536 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761562652.668381    6536 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-27 10:57:32.673281: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Step 2/6] inverse_folding - Predicting DataLoader 0: : 100% 10/10 [00:13<00:00,  1.31s/it]Number of failed examples: 0
# [Step 2/6] inverse_folding - Predicting DataLoader 0: : 100% 10/10 [00:13<00:00,  1.31s/it]
# ✓ Step inverse_folding completed successfully in 34.8s
# **************************************************
# Pipeline step 3 of 6: folding
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/folding.yaml
# Initializing FromGeneratedDataModule datasets for workbench/test_run/intermediate_designs_inverse_folded
# [Info] Number of files to process (including already processed ones): 10
# Found 1 targets and 10 remaining designs that still need to be processed in this step.
# [Step 3/6] folding - Predicting DataLoader 0: : 100% 10/10 [19:11<00:00, 115.12s/it]Number of failed structure predictions: 0
# [Step 3/6] folding - Predicting DataLoader 0: : 100% 10/10 [19:11<00:00, 115.12s/it]
# ✓ Step folding completed successfully in 1218.2s
# **************************************************
# Pipeline step 4 of 6: design_folding
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/design_folding.yaml
# Initializing FromGeneratedDataModule datasets for workbench/test_run/intermediate_designs_inverse_folded
# [Info] Number of files to process (including already processed ones): 10
# Found 1 targets and 10 remaining designs that still need to be processed in this step.
# [Step 4/6] design_folding - Predicting DataLoader 0: : 100% 10/10 [05:17<00:00, 31.71s/it]Number of failed structure predictions: 0
# [Step 4/6] design_folding - Predicting DataLoader 0: : 100% 10/10 [05:17<00:00, 31.71s/it]
# ✓ Step design_folding completed successfully in 387.4s
# **************************************************
# Pipeline step 5 of 6: analysis
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/analysis.yaml
# Initializing FromGeneratedDataModule datasets for workbench/test_run/intermediate_designs_inverse_folded
# [Info] Number of files to process (including already processed ones): 10
# Found 1 targets and 10 remaining designs that still need to be processed in this step.
# Processing samples: 100% 10/10 [00:32<00:00,  3.27s/it]
# Computed metrics successfully for 10 out of 10.
# Loading saved metrics from disk. 1% of total: 100% 10/10 [00:00<00:00, 56.71it/s]
# Number of targets: 1. Number of designs: 10.
# ✓ Step analysis completed successfully in 49.2s
# **************************************************
# Pipeline step 6 of 6: filtering
# Running command: python /usr/local/lib/python3.12/dist-packages/boltzgen/resources/main.py workbench/test_run/config/filtering.yaml
# Total number of designs:    10
# Duplicates found: 0. Removing duplicates. 10 designs remain.
#
# Num designs that pass the has_x filter with threshold 0 where lower is better: 10
# Remaining designs: 10
# Num designs that pass the filter_rmsd filter with threshold 2.5 where lower is better: 3
# Remaining designs: 3
# Num designs that pass the filter_rmsd_design filter with threshold 2.5 where lower is better: 5
# Remaining designs: 3
# Num designs that pass the designfolding-filter_rmsd filter with threshold 2.5 where lower is better: 2
# Remaining designs: 0
# Num designs that pass the ALA_fraction filter with threshold 0.2 where lower is better: 6
# Remaining designs: 0
# Num designs that pass the GLY_fraction filter with threshold 0.2 where lower is better: 7
# Remaining designs: 0
# Num designs that pass the GLU_fraction filter with threshold 0.2 where lower is better: 10
# Remaining designs: 0
# Num designs that pass the LEU_fraction filter with threshold 0.2 where lower is better: 9
# Remaining designs: 0
# Num designs that pass the VAL_fraction filter with threshold 0.2 where lower is better: 10
# Remaining designs: 0
# Only 0 designs pass filters. We highly recommend relaxing the thresholds.
#
#
# Performing lazy greedy diversity optimization.: 100% 1/1 [00:00<00:00, 10034.22it/s]
# copy top design files: 10it [00:00, 1406.16it/s]
# copy diversity files: 100% 2/2 [00:00<00:00, 1385.17it/s]
# Files + CSV saved to workbench/test_run/final_ranked_designs
#
# Writing design files is done. Now making plots for a final summary .pdf file with statistics.
# Making liability plots for top 0 sequences.: 0it [00:00, ?it/s]
# A description of metrics and summarizing plots was written to: workbench/test_run/final_ranked_designs/results_overview.pdf
# ✓ Step filtering completed successfully in 19.5s

# %%
#@title Download results
import pathlib
from google.colab import files

folder_name = "workbench/test_run" #@param {type:"string"}

if not pathlib.Path(folder_name).exists():
  print(f'Specified folder "{folder_name}" does not exits. Do nothing.')
else:
  print(f'Downloading results from "{folder_name}". Zipping...\n=====\n')
  outname = f'{folder_name}.result.zip'
  # !zip -q -r {outname} {folder_name}
  print(f'Done\n\nDownload "{outname}"')
  files.download(outname)
# Out:
# Specified folder "workbench/test_ru" does not exits. Do nothing.
